# %% [markdown]
# ### Fruit Recommendation System using Content-Based Filtering and Cosine Similarity

# %% [markdown]
# # Problem Statement
#
# People often want to choose foods with similar nutritional values for:
#
#     healthy diet planning
#
#     nutritional substitution
#
#     meal recommendations
#
# However, it is difficult to manually compare the nutritional values of many fruits.
#
# Therefore, we build a recommendation system that automatically finds nutritionally similar fruits.

# %% [markdown]
# | Column      | Description    |
# | ----------- | -------------- |
# | fruit_100g  | Name of fruit  |
# | energy_kcal | Energy content |
# | water_g     | Water content  |
# | protein_g   | Protein        |
# | fat_g       | Fat            |
# | fiber_g     | Dietary fiber  |
# | sugars_g    | Sugar content  |
# | vitaminc_mg | Vitamin C      |

# %%
import pandas as pd

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

# %%
# Load data

df = pd.read_csv("fruit_dataset_100.csv")
df
# Out:
#        fruit_100g  energy_kcal  water_g  protein_g  totalfat_g  fiber_g  \
# 0          Banana         51.1     77.9       2.95        3.17     3.99
# 1           Apple        228.8     70.0       1.38        4.05     4.49
# 2          Orange        233.4     88.9       2.01       13.11     1.21
# 3           Lemon        242.1     84.5       1.67       10.74     1.07
# 4            Lime        231.1     81.9       1.00        8.82     2.25
# ..            ...          ...      ...        ...         ...      ...
# 95      Longan_95         30.7     77.7       1.09        0.19     3.37
# 96     Soursop_96        169.1     67.6       2.75        8.07     9.14
# 97  Breadfruit_97        127.2     74.3       0.89        7.56     2.65
# 98      Banana_98        223.4     69.8       3.35       13.08     2.90
# 99       Apple_99         22.0     60.2       1.83        0.21     6.66
#
#     sugars_g  vitaminc_mg
# 0      17.64         27.6
# 1       7.17         67.4
# 2      22.34         28.2
# 3      24.93         66.6
# 4       7.57         16.0
# ..       ...          ...
# 95      5.29         85.4
# 96      9.72         69.0
# 97     10.15         77.2
# 98      1.42         33.1
# 99      7.06         78.9
#
# [100 rows x 8 columns]

# %%
# Set fruit name as index

df = df.set_index("fruit_100g")

df.index.name = None

# %%
df
# Out:
#                energy_kcal  water_g  protein_g  totalfat_g  fiber_g  sugars_g  \
# Banana                51.1     77.9       2.95        3.17     3.99     17.64
# Apple                228.8     70.0       1.38        4.05     4.49      7.17
# Orange               233.4     88.9       2.01       13.11     1.21     22.34
# Lemon                242.1     84.5       1.67       10.74     1.07     24.93
# Lime                 231.1     81.9       1.00        8.82     2.25      7.57
# ...                    ...      ...        ...         ...      ...       ...
# Longan_95             30.7     77.7       1.09        0.19     3.37      5.29
# Soursop_96           169.1     67.6       2.75        8.07     9.14      9.72
# Breadfruit_97        127.2     74.3       0.89        7.56     2.65     10.15
# Banana_98            223.4     69.8       3.35       13.08     2.90      1.42
# Apple_99              22.0     60.2       1.83        0.21     6.66      7.06
#
#                vitaminc_mg
# Banana                27.6
# Apple                 67.4
# Orange                28.2
# Lemon                 66.6
# Lime                  16.0
# ...                    ...
# Longan_95             85.4
# Soursop_96            69.0
# Breadfruit_97         77.2
# Banana_98             33.1
# Apple_99              78.9
#
# [100 rows x 7 columns]

# %%
# Use ALL numeric columns automatically

features = df.select_dtypes(include=['number'])

# %%
features.index
# Out:
# Index(['Banana', 'Apple', 'Orange', 'Lemon', 'Lime', 'Mango', 'Peach',
#        'Pineapple', 'Grapes', 'Strawberry', 'Blueberry', 'Raspberry',
#        'Blackberry', 'Watermelon', 'Muskmelon', 'Pomegranate', 'Pear', 'Plum',
#        'Cherry', 'Apricot', 'Avocado', 'Coconut', 'Fig', 'Date', 'Dragonfruit',
#        'Lychee', 'Jackfruit', 'Guava', 'Custard Apple', 'Kiwi', 'Papaya',
#        'Passionfruit', 'Cranberry', 'Mulberry', 'Gooseberry', 'Tamarind',
#        'Sapota', 'Starfruit', 'Rambutan', 'Durian', 'Persimmon', 'Nectarine',
#        'Olive', 'Boysenberry', 'Elderberry', 'Acai', 'Longan', 'Soursop',
#        'Breadfruit', 'Banana_49', 'Apple_50', 'Orange_51', 'Lemon_52',
#        'Lime_53', 'Mango_54', 'Peach_55', 'Pineapple_56', 'Grapes_57',
#        'Strawberry_58', 'Blueberry_59', 'Raspberry_60', 'Blackberry_61',
#        'Watermelon_62', 'Muskmelon_63', 'Pomegranate_64', 'Pear_65', 'Plum_66',
#        'Cherry_67', 'Apricot_68', 'Avocado_69', 'Coconut_70', 'Fig_71',
#        'Date_72', 'Dragonfruit_73', 'Lychee_74', 'Jackfruit_75', 'Guava_76',
#        'Custard Apple_77', 'Kiwi_78', 'Papaya_79', 'Passionfruit_80',
#        'Cranberry_81', 'Mulberry_82', 'Gooseberry_83', 'Tamarind_84',
#        'Sapota_85', 'Starfruit_86', 'Rambutan_87', 'Durian_88', 'Persimmon_89',
#        'Nectarine_90', 'Olive_91', 'Boysenberry_92', 'Elderberry_93',
#        'Acai_94', 'Longan_95', 'Soursop_96', 'Breadfruit_97', 'Banana_98',
#        'Apple_99'],
#       dtype='object')

# %%
#  APPLY SCALING HERE

scaler = MinMaxScaler()

features_scaled = scaler.fit_transform(features)

# %%
features_scaled
# Out:
# array([[0.11256354, 0.51603499, 0.84735202, 0.20452986, 0.36853221,
#         0.69382612, 0.26109391],
#        [0.75780683, 0.28571429, 0.35825545, 0.26492793, 0.42133052,
#         0.25409492, 0.67182663],
#        [0.7745098 , 0.83673469, 0.55451713, 0.8867536 , 0.0749736 ,
#         0.89122218, 0.26728586],
#        [0.80610022, 0.70845481, 0.44859813, 0.7240906 , 0.06019007,
#         1.        , 0.66357069],
#        [0.76615832, 0.63265306, 0.23987539, 0.59231297, 0.18479409,
#         0.27089458, 0.14138287],
#        [0.07443718, 0.11953353, 0.105919  , 0.702814  , 0.58922914,
#         0.48677026, 0.54385965],
#        [0.89215686, 0.2361516 , 0.01246106, 0.73026767, 0.        ,
#         0.61066779, 0.97316821],
#        [0.98184459, 0.93877551, 0.24299065, 0.44543583, 0.22597677,
#         0.39941201, 0.750258  ],
#        [0.33405955, 0.00291545, 0.18068536, 0.13658202, 0.85427666,
#         0.62284754, 0.14138287],
#        [0.76797386, 0.75510204, 0.19937695, 0.91352093, 0.18479409,
#         0.76270475, 0.03921569],
#        [0.32207698, 0.0058309 , 1.        , 0.89910776, 0.42977825,
#         0.54682906, 0.49329205],
#        [0.9644154 , 0.19825073, 0.30529595, 0.41111874, 0.65153115,
#         0.47711046, 0.91434469],
#        [1.        , 0.20408163, 0.57632399, 0.72889499, 0.40865892,
#         0.11549769, 0.29824561],
#        [0.06572259, 0.78717201, 0.94392523, 0.14893617, 0.48574446,
#         0.80260395, 0.83591331],
#        [0.15976761, 0.08163265, 0.51090343, 0.07000686, 0.48574446,
#         0.41663167, 0.50154799],
#        [0.03848947, 0.51020408, 0.26791277, 0.        , 0.3030623 ,
#         0.1751365 , 0.85758514],
#        [0.54103123, 0.21574344, 0.78504673, 0.54083734, 0.9123548 ,
#         0.36119278, 0.68833849],
#        [0.38888889, 0.41107872, 0.20560748, 0.50583391, 0.22703273,
#         0.37925241, 0.77296182],
#        [0.73819898, 0.27988338, 0.97196262, 0.88469458, 0.25343189,
#         0.01259975, 0.31785346],
#        [0.00689906, 0.        , 0.49844237, 0.00137268, 0.65047518,
#         0.24947501, 0.79050568]])

# %%
# Compute cosine similarity

similarity_matrix = cosine_similarity(features_scaled)

# %%
similarity_matrix
# Out:
# array([[1.        , 0.67179355, 0.79486392, ..., 0.69378135, 0.68041712,
#         0.68118676],
#        [0.67179355, 1.        , 0.75493967, ..., 0.90066029, 0.78313509,
#         0.72588406],
#        [0.79486392, 0.75493967, 1.        , ..., 0.82426252, 0.78311125,
#         0.3633626 ],
#        ...,
#        [0.69378135, 0.90066029, 0.82426252, ..., 1.        , 0.7204061 ,
#         0.69268681],
#        [0.68041712, 0.78313509, 0.78311125, ..., 0.7204061 , 1.        ,
#         0.49218151],
#        [0.68118676, 0.72588406, 0.3633626 , ..., 0.69268681, 0.49218151,
#         1.        ]])

# %%
# Convert to DataFrame

similarity_df = pd.DataFrame(
    similarity_matrix,
    index=features.index,
    columns=features.index
)

# %%
similarity_df
# Out:
#                  Banana     Apple    Orange     Lemon      Lime     Mango  \
# Banana         1.000000  0.671794  0.794864  0.783043  0.635641  0.642799
# Apple          0.671794  1.000000  0.754940  0.834058  0.811413  0.713403
# Orange         0.794864  0.754940  1.000000  0.965991  0.930044  0.683069
# Lemon          0.783043  0.834058  0.965991  1.000000  0.879505  0.733408
# Lime           0.635641  0.811413  0.930044  0.879505  1.000000  0.609767
# ...                 ...       ...       ...       ...       ...       ...
# Longan_95      0.664011  0.750522  0.513730  0.640984  0.475982  0.635675
# Soursop_96     0.796941  0.900056  0.705482  0.738642  0.703906  0.832641
# Breadfruit_97  0.693781  0.900660  0.824263  0.909523  0.791843  0.848073
# Banana_98      0.680417  0.783135  0.783111  0.729478  0.814754  0.607118
# Apple_99       0.681187  0.725884  0.363363  0.491143  0.295573  0.715753
#
#                   Peach  Pineapple    Grapes  Strawberry  ...  Nectarine_90  \
# Banana         0.490815   0.650339  0.767816    0.637084  ...      0.814318
# Apple          0.855440   0.909042  0.902082    0.779543  ...      0.738984
# Orange         0.789848   0.864445  0.915063    0.906057  ...      0.769038
# Lemon          0.893205   0.905594  0.926164    0.906387  ...      0.764503
# Lime           0.774188   0.919377  0.931060    0.922254  ...      0.658450
# ...                 ...        ...       ...         ...  ...           ...
# Longan_95      0.612521   0.736635  0.651886    0.503243  ...      0.525755
# Soursop_96     0.678617   0.731340  0.826679    0.623321  ...      0.892603
# Breadfruit_97  0.921160   0.906201  0.872905    0.778200  ...      0.763932
# Banana_98      0.651570   0.713183  0.733432    0.585904  ...      0.884540
# Apple_99       0.487700   0.489768  0.545536    0.303010  ...      0.690626
#
#                Olive_91  Boysenberry_92  Elderberry_93   Acai_94  Longan_95  \
# Banana         0.629653        0.601122       0.948297  0.860317   0.664011
# Apple          0.982455        0.881725       0.738794  0.815318   0.750522
# Orange         0.726552        0.797326       0.733670  0.609823   0.513730
# Lemon          0.823684        0.772155       0.785979  0.697643   0.640984
# Lime           0.766447        0.887004       0.591385  0.505999   0.475982
# ...                 ...             ...            ...       ...        ...
# Longan_95      0.713922        0.432939       0.862371  0.781027   1.000000
# Soursop_96     0.896569        0.849119       0.807450  0.923447   0.710788
# Breadfruit_97  0.899837        0.757597       0.800847  0.766780   0.831239
# Banana_98      0.722348        0.940638       0.613198  0.635380   0.452337
# Apple_99       0.741282        0.480302       0.800986  0.939220   0.827222
#
#                Soursop_96  Breadfruit_97  Banana_98  Apple_99
# Banana           0.796941       0.693781   0.680417  0.681187
# Apple            0.900056       0.900660   0.783135  0.725884
# Orange           0.705482       0.824263   0.783111  0.363363
# Lemon            0.738642       0.909523   0.729478  0.491143
# Lime             0.703906       0.791843   0.814754  0.295573
# ...                   ...            ...        ...       ...
# Longan_95        0.710788       0.831239   0.452337  0.827222
# Soursop_96       1.000000       0.827271   0.829478  0.850019
# Breadfruit_97    0.827271       1.000000   0.720406  0.692687
# Banana_98        0.829478       0.720406   1.000000  0.492182
# Apple_99         0.850019       0.692687   0.492182  1.000000
#
# [100 rows x 100 columns]

# %%
# Recommendation function

def recommend_fruits(fruit_name, top_n=2):
    fruit_name = fruit_name.strip().title()
    
    if fruit_name not in similarity_df.index:
        return f"{fruit_name} not found in dataset"
    
    similar = similarity_df[fruit_name].sort_values(ascending=False)
    
    result = similar.iloc[1:top_n+1]
    
    result = (result * 100).round(2)
    
    return result.to_frame(name="Similarity (%)")

# %%
print(recommend_fruits("Mango"))
# Out:
#              Similarity (%)
# Apricot_68            91.92
# Rambutan_87           91.31

# %%
print(recommend_fruits("Kiwi"))
# Out:
#          Similarity (%)
# Plum              98.51
# Coconut           98.07
